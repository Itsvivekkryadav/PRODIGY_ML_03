# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
from skimage.io import imread
from skimage.transform import resize
from sklearn.model_selection import train_test_split

# %%
plt.figure(figsize=(10,5))
img1 = r"C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.78.jpg"
plt.imshow(imread(img1))

# %%
img_path = r"C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.78.jpg"
img = imread(img_path)
img
# Out:
# array([[[164, 128, 112],
#         [163, 127, 111],
#         [163, 127, 111],
#         ...,
#         [133,  98,  78],
#         [133,  98,  78],
#         [133,  98,  78]],
#
#        [[162, 126, 110],
#         [162, 126, 110],
#         [162, 126, 110],
#         ...,
#         [131,  99,  78],
#         [131,  99,  78],
#         [131,  99,  78]],
#
#        [[160, 124, 108],
#         [160, 124, 108],
#         [161, 125, 109],
#         ...,
#         [131,  99,  76],
#         [131,  99,  76],
#         [131,  99,  76]],
#
#        ...,
#
#        [[148,  27,  58],
#         [150,  29,  60],
#         [142,  21,  52],
#         ...,
#         [156,  31,  63],
#         [156,  31,  63],
#         [156,  31,  63]],
#
#        [[151,  30,  61],
#         [153,  32,  63],
#         [143,  22,  53],
#         ...,
#         [156,  31,  63],
#         [156,  31,  63],
#         [156,  31,  63]],
#
#        [[153,  32,  63],
#         [154,  33,  64],
#         [144,  23,  54],
# ...

# %%
img.shape
# Out:
# (499, 499, 3)

# %%
img_resize = resize(img, (15, 15))
img_resize.shape
# Out:
# (15, 15, 3)

# %%
img_resize
# Out:
# array([[[0.63552634, 0.50096774, 0.43092317],
#         [0.64004555, 0.51072077, 0.44057545],
#         [0.60233615, 0.48950861, 0.44084657],
#         [0.62899958, 0.51845533, 0.48445812],
#         [0.61444715, 0.51287531, 0.49604664],
#         [0.59735185, 0.49711004, 0.47943283],
#         [0.62837062, 0.51792903, 0.49619426],
#         [0.63655072, 0.51162727, 0.47065668],
#         [0.64052554, 0.50770003, 0.46244281],
#         [0.62698549, 0.49473356, 0.44916166],
#         [0.61008938, 0.48342112, 0.44115791],
#         [0.58881511, 0.46650939, 0.42587228],
#         [0.55517477, 0.43273175, 0.37263142],
#         [0.5047328 , 0.38779302, 0.30359559],
#         [0.49333876, 0.3792029 , 0.29107234]],
#
#        [[0.63104177, 0.50530973, 0.44608144],
#         [0.63049812, 0.51164944, 0.45595879],
#         [0.49358021, 0.39988367, 0.36405397],
#         [0.42990135, 0.34314002, 0.30541649],
#         [0.43415809, 0.35216373, 0.32780178],
# ...

# %%
flatten_img = img_resize.flatten()
flatten_img
# Out:
# array([0.63552634, 0.50096774, 0.43092317, 0.64004555, 0.51072077,
#        0.44057545, 0.60233615, 0.48950861, 0.44084657, 0.62899958,
#        0.51845533, 0.48445812, 0.61444715, 0.51287531, 0.49604664,
#        0.59735185, 0.49711004, 0.47943283, 0.62837062, 0.51792903,
#        0.49619426, 0.63655072, 0.51162727, 0.47065668, 0.64052554,
#        0.50770003, 0.46244281, 0.62698549, 0.49473356, 0.44916166,
#        0.61008938, 0.48342112, 0.44115791, 0.58881511, 0.46650939,
#        0.42587228, 0.55517477, 0.43273175, 0.37263142, 0.5047328 ,
#        0.38779302, 0.30359559, 0.49333876, 0.3792029 , 0.29107234,
#        0.63104177, 0.50530973, 0.44608144, 0.63049812, 0.51164944,
#        0.45595879, 0.49358021, 0.39988367, 0.36405397, 0.42990135,
#        0.34314002, 0.30541649, 0.43415809, 0.35216373, 0.32780178,
#        0.449158  , 0.35241563, 0.33831424, 0.58391076, 0.47750919,
#        0.45153912, 0.61225087, 0.4891862 , 0.4457413 , 0.616404  ,
# ...

# %%
flatten_img.shape
# Out:
# (675,)

# %%
input_dir = r"C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train"
categories = ['cats','dogs']
data = []
labels = []

for category_idx, category in enumerate(categories):
    for file in os.listdir(os.path.join(input_dir, category)):
        img_path = os.path.join(input_dir, category, file)
        print(img_path)
        img = imread(img_path)
        img = resize(img, (15,15))
        data.append(img.flatten())
        labels.append(category_idx)
# Out:
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.0.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.1.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.100.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.1000.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10000.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10001.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10002.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10003.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10004.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10005.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10006.jpg
# C:\Users\acer\OneDrive\Desktop\ML DataSet\model-3\train\cats\cat.10007.jpg
# ...

# %%
data[1]
# Out:
# array([0.15475881, 0.17823866, 0.18050522, 0.16481283, 0.19132771,
#        0.19599281, 0.17993837, 0.19631279, 0.22080601, 0.24813205,
#        0.26625759, 0.3242322 , 0.29820702, 0.31991942, 0.39023424,
#        0.4863408 , 0.42609549, 0.47295349, 0.55818624, 0.46712147,
#        0.50036804, 0.55489821, 0.46787954, 0.51127193, 0.55253738,
#        0.46004273, 0.50912766, 0.52188816, 0.44237382, 0.49909265,
#        0.35295823, 0.37568898, 0.49995301, 0.29976216, 0.33618772,
#        0.45851706, 0.30648234, 0.32899316, 0.4304933 , 0.30179945,
#        0.32561266, 0.41941173, 0.45257153, 0.46074022, 0.48214521,
#        0.14760614, 0.17559295, 0.17156327, 0.16571784, 0.19277159,
#        0.20370451, 0.20284079, 0.22690963, 0.25642246, 0.27471546,
#        0.28725622, 0.34438327, 0.30062985, 0.31437683, 0.38459694,
#        0.46238836, 0.39389409, 0.42427697, 0.53535566, 0.42442021,
#        0.43332364, 0.53500832, 0.4197014 , 0.42510027, 0.53019404,
# ...

# %%
labels[1]
# Out:
# 0

# %%
data = np.asarray(data)
labels = np.asarray(labels)

# %%
data.shape
# Out:
# (25000, 675)

# %%
labels
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, stratify=labels)

# %%
from sklearn.svm import SVC
svm_model = SVC()

# %%
svm_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.6846

# %%
from sklearn.model_selection import cross_val_score
cross_val_score = cross_val_score(svm_model, data, labels, cv=5)
cross_val_score
# Out:
# array([0.6808, 0.6774, 0.6884, 0.6826, 0.6892])

# %%
Mean_Accuracy = cross_val_score.mean()
Mean_Accuracy
# Out:
# 0.6836800000000001

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69      2500
#            1       0.69      0.68      0.68      2500
#
#     accuracy                           0.68      5000
#    macro avg       0.68      0.68      0.68      5000
# weighted avg       0.68      0.68      0.68      5000
